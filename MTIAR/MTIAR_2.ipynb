# %% [markdown]
# # Романченко Д. ФИ-92
# ### Comments:
# ### Automation of regular actions simplifies lots of manual work. In order to follow this principle
# ### this lab was completed using Python

# %%
# Імпорт необхідних бібліотек
import pandas as pd
import statistics as stat

# %%
# Вхідні дані
raw_data = pd.read_csv('data.csv')

group1_age = [17, 16, 17, 18, 18, 17, 17, 17, 16, 18, 18, 18, 17, 17, 17, 17, 17, 18]
group2_age = [18, 19, 19, 17, 17, 17, 17, 17, 17, 17, 17, 17, 18, 16, 19, 18, 17, 17, 18, 17]
group3_age = [17, 17, 17, 17, 18, 17, 18, 17, 18, 21, 19, 17, 17, 17, 17, 18, 17, 18, 17]

raw_data
# Out:
#      Group  Total amount  Male  Female  Kyiv citizens  Dormitory  Other
# 0  Group 1            18    15       3              7         10      1
# 1  Group 2            20    12       8              8          8      4
# 2  Group 3            19    12       7              5          9      5

# %%
print("----------------------------------------")
print("Max")
print("----------------------------------------")
print(f"Max age of 'Group 1': {max(group1_age)}")
print(f"Max age of 'Group 2': {max(group2_age)}")
print(f"Max age of 'Group 3': {max(group3_age)}")
print(f"Max amount of males: {max(raw_data['Male'])}")
print(f"Max amount of females: {max(raw_data['Female'])}")
print(f"Max amount of Kyiv citizens: {max(raw_data['Kyiv citizens'])}")
print(f"Max amount of dormitory residents: {max(raw_data['Dormitory'])}")
print(f"Max amount of neither Kyiv citizens nor dormitory residents: {max(raw_data['Other'])}")

print("----------------------------------------")
print("Min values")
print("----------------------------------------")

print(f"Min age of 'Group 1': {min(group1_age)}")
print(f"Min age of 'Group 2': {min(group2_age)}")
print(f"Min age of 'Group 3': {min(group3_age)}")
print(f"Min amount of males: {min(raw_data['Male'])}")
print(f"Min amount of females: {min(raw_data['Female'])}")
print(f"Min amount of Kyiv citizens: {min(raw_data['Kyiv citizens'])}")
print(f"Min amount of dormitory residents: {min(raw_data['Dormitory'])}")
print(f"Min amount of neither Kyiv citizens nor dormitory residents: {min(raw_data['Other'])}")

print("----------------------------------------")
print("Variation")
print("----------------------------------------")

print(f"Age variation of 'Group 1': {max(group1_age) - min(group1_age)}")
print(f"Age variation of 'Group 2': {max(group2_age) - min(group2_age)}")
print(f"Age variation of 'Group 3': {max(group3_age) - min(group3_age)}")
print(f"Amount variation of males: {max(raw_data['Male']) - min(raw_data['Male'])}")
print(f"Amount variation of females: {max(raw_data['Female']) -min(raw_data['Female'])}")
print(f"Amount variation of Kyiv citizens: {max(raw_data['Kyiv citizens']) -min(raw_data['Kyiv citizens'])}")
print(f"Amount variation of dormitory residents: {max(raw_data['Dormitory']) - min(raw_data['Dormitory'])}")
print(f"Amount variation of neither Kyiv citizens nor dormitory residents: {max(raw_data['Other']) -min(raw_data['Other'])}")

print("----------------------------------------")
print("Mode")
print("----------------------------------------")

print(f"Age mode of 'Group 1': {stat.mode(group1_age)}")
print(f"Age mode of 'Group 2': {stat.mode(group2_age)}")
print(f"Age mode of 'Group 3': {stat.mode(group3_age)}")

print("----------------------------------------")
print("Median")

print(f"Age median of 'Group 1': {stat.median(group1_age)}")
print(f"Age median of 'Group 2': {stat.median(group2_age)}")
print(f"Age median of 'Group 3': {stat.median(group3_age)}")

print("----------------------------------------")
print("Quartiles")

print(f"Quartiles age of 'Group 1': {stat.quantiles(group1_age, n = 4)}")
print(f"Quartiles age of 'Group 2': {stat.quantiles(group2_age, n = 4)}")
print(f"Quartiles age of 'Group 3': {stat.quantiles(group3_age, n = 4)}")
print(f"Quartiles of males: {stat.quantiles(raw_data['Male'], n = 4)}")
print(f"Quartiles of females: {stat.quantiles(raw_data['Female'], n = 4)}")
print(f"Quartiles of Kyiv citizens: {stat.quantiles(raw_data['Kyiv citizens'], n = 4)}")
print(f"Quartiles of dormitory residents: {stat.quantiles(raw_data['Dormitory'], n = 4)}")
print(f"Quartiles of neither Kyiv citizens nor dormitory residents: {stat.quantiles(raw_data['Other'], n = 4)}")

print("----------------------------------------")
print("Quantiles")

print(f"Quantiles age of 'Group 1': {stat.quantiles(group1_age, n = 5)}")
print(f"Quantiles age of 'Group 2': {stat.quantiles(group2_age, n = 5)}")
print(f"Quantiles age of 'Group 3': {stat.quantiles(group3_age, n = 5)}")
print(f"Quantiles of males: {stat.quantiles(raw_data['Male'], n = 5)}")
print(f"Quantiles of females: {stat.quantiles(raw_data['Female'], n = 5)}")
print(f"Quantiles of Kyiv citizens: {stat.quantiles(raw_data['Kyiv citizens'], n = 5)}")
print(f"Quantiles of dormitory residents: {stat.quantiles(raw_data['Dormitory'], n = 5)}")
print(f"Quantiles of neither Kyiv citizens nor dormitory residents: {stat.quantiles(raw_data['Other'], n = 5)}")

print("----------------------------------------")
print("Deciles")

print(f"Deciles age of 'Group 1': {stat.quantiles(group1_age, n = 10)}")
print(f"Deciles age of 'Group 2': {stat.quantiles(group2_age, n = 10)}")
print(f"Deciles age of 'Group 3': {stat.quantiles(group3_age, n = 10)}")
print(f"Deciles of males: {stat.quantiles(raw_data['Male'], n = 10)}")
print(f"Deciles of females: {stat.quantiles(raw_data['Female'], n = 10)}")
print(f"Deciles of Kyiv citizens: {stat.quantiles(raw_data['Kyiv citizens'], n = 10)}")
print(f"Deciles of dormitory residents: {stat.quantiles(raw_data['Dormitory'], n = 10)}")
print(f"Deciles of neither Kyiv citizens nor dormitory residents: {stat.quantiles(raw_data['Other'], n = 10)}")

print("----------------------------------------")
print("Percentiles")

print(f"Percentiles age of 'Group 1': {stat.quantiles(group1_age, n = 100)}")
print(f"Percentiles age of 'Group 2': {stat.quantiles(group2_age, n = 100)}")
print(f"Percentiles age of 'Group 3': {stat.quantiles(group3_age, n = 100)}")
print(f"Percentiles of males: {stat.quantiles(raw_data['Male'], n = 100)}")
print(f"Percentiles of females: {stat.quantiles(raw_data['Female'], n = 100)}")
print(f"Percentiles of Kyiv citizens: {stat.quantiles(raw_data['Kyiv citizens'], n = 100)}")
print(f"Percentiles of dormitory residents: {stat.quantiles(raw_data['Dormitory'], n = 100)}")
print(f"Percentiles of neither Kyiv citizens nor dormitory residents: {stat.quantiles(raw_data['Other'], n = 100)}")

print("----------------------------------------")
print("Arithmetic mean")

print(f"Mean age of 'Group 1': {stat.mean(group1_age)}")
print(f"Mean age of 'Group 2': {stat.mean(group2_age)}")
print(f"Mean age of 'Group 3': {stat.mean(group3_age)}")
print(f"Mean amount of males: {stat.mean(raw_data['Male'])}")
print(f"Mean amount of females: {stat.mean(raw_data['Female'])}")
print(f"Mean amount of Kyiv citizens: {stat.mean(raw_data['Kyiv citizens'])}")
print(f"Mean amount of dormitory residents: {stat.mean(raw_data['Dormitory'])}")
print(f"Mean amount of neither Kyiv citizens nor dormitory residents: {stat.mean(raw_data['Other'])}")

print("----------------------------------------")
print("Geometric mean")

print(f"Mean age of 'Group 1': {stat.geometric_mean(group1_age)}")
print(f"Mean age of 'Group 2': {stat.geometric_mean(group2_age)}")
print(f"Mean age of 'Group 3': {stat.geometric_mean(group3_age)}")
print(f"Mean amount of males: {stat.geometric_mean(raw_data['Male'])}")
print(f"Mean amount of females: {stat.geometric_mean(raw_data['Female'])}")
print(f"Mean amount of Kyiv citizens: {stat.geometric_mean(raw_data['Kyiv citizens'])}")
print(f"Mean amount of dormitory residents: {stat.geometric_mean(raw_data['Dormitory'])}")
print(f"Mean amount of neither Kyiv citizens nor dormitory residents: {stat.geometric_mean(raw_data['Other'])}")

print("----------------------------------------")
print("Harmonic mean")

print(f"Mean age of 'Group 1': {stat.harmonic_mean(group1_age)}")
print(f"Mean age of 'Group 2': {stat.harmonic_mean(group2_age)}")
print(f"Mean age of 'Group 3': {stat.harmonic_mean(group3_age)}")
print(f"Mean amount of males: {stat.harmonic_mean(raw_data['Male'])}")
print(f"Mean amount of females: {stat.harmonic_mean(raw_data['Female'])}")
print(f"Mean amount of Kyiv citizens: {stat.harmonic_mean(raw_data['Kyiv citizens'])}")
print(f"Mean amount of dormitory residents: {stat.harmonic_mean(raw_data['Dormitory'])}")
print(f"Mean amount of neither Kyiv citizens nor dormitory residents: {stat.harmonic_mean(raw_data['Other'])}")

print("----------------------------------------")
print("Standard deviation")

print(f"Deviation age of 'Group 1': {stat.stdev(group1_age)}")
print(f"Deviation age of 'Group 2': {stat.stdev(group2_age)}")
print(f"Deviation age of 'Group 3': {stat.stdev(group3_age)}")
print(f"Deviation of males: {stat.stdev(raw_data['Male'])}")
print(f"Deviation of females: {stat.stdev(raw_data['Female'])}")
print(f"Deviation of Kyiv citizens: {stat.stdev(raw_data['Kyiv citizens'])}")
print(f"Deviation of dormitory residents: {stat.stdev(raw_data['Dormitory'])}")
print(f"Deviation of neither Kyiv citizens nor dormitory residents: {stat.stdev(raw_data['Other'])}")

print("----------------------------------------")
print("Variance")

print(f"Variance age of 'Group 1': {stat.variance(group1_age)}")
print(f"Variance age of 'Group 2': {stat.variance(group2_age)}")
print(f"Variance age of 'Group 3': {stat.variance(group3_age)}")
print(f"Variance of males: {stat.variance(raw_data['Male'])}")
print(f"Variance of females: {stat.variance(raw_data['Female'])}")
print(f"Variance of Kyiv citizens: {stat.variance(raw_data['Kyiv citizens'])}")
print(f"Variance of dormitory residents: {stat.variance(raw_data['Dormitory'])}")
print(f"Variance of neither Kyiv citizens nor dormitory residents: {stat.variance(raw_data['Other'])}")
# Out:
# ----------------------------------------
# MAX
# ----------------------------------------
# Max age of 'Group 1': 18
# Max age of 'Group 2': 19
# Max age of 'Group 3': 21
# Max amount of males: 15
# Max amount of females: 8
# Max amount of Kyiv citizens: 8
# Max amount of dormitory residents: 10
# Max amount of neither Kyiv citizens nor dormitory residents: 5
# ----------------------------------------
# MIN
# ----------------------------------------
# Min age of 'Group 1': 16
# Min age of 'Group 2': 16
# Min age of 'Group 3': 17
# Min amount of males: 12
# Min amount of females: 3
# Min amount of Kyiv citizens: 5
# Min amount of dormitory residents: 8
# Min amount of neither Kyiv citizens nor dormitory residents: 1
# ----------------------------------------
# Variation
# ----------------------------------------
# Age variation of 'Group 1': 2
# Age variation of 'Group 2': 3
# Age variation of 'Group 3': 4
# Amount variation of males: 3
# Amount variation of females: 5
# ...
